# %% [markdown]
# <a href="https://colab.research.google.com/github/jongwoo1126/Colab/blob/master/Ch01.%20%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EA%B8%B0%EC%B4%88/7_%ED%85%8D%EC%8A%A4%ED%8A%B8_%EC%8B%9C%EA%B0%81%ED%99%94_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 한글 형태소 분석기 설치
# !pip3 install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 49.7 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.2.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0

# %%
"""
날짜 : 2022/04/27
이름 : 박종우
내용 : 파이썬 텍스트 시각화 실습하기
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from PIL import Image
from konlpy.tag import Okt

# %%
# 데이터 불러오기
txt_data = open('/content/drive/MyDrive/파이썬 데이터 과학 실습/file/wordcloud_data.txt').read()
txt_data

# %%
# 택스트 시각화(단어구름)
wc = WordCloud(width=1200,
               height=1200,
               background_color='white',
               font_path='/content/drive/MyDrive/파이썬 데이터 과학 실습/file/malgun.ttf').generate(txt_data)

plt.title('Text Word Cloud')
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
# 텍스트 형태소 분석기 생성
okt = Okt()
okt

# %%
# 형태소 분석
result1 = okt.pos('아버지가 방에 들어가십니다.')
result2 = okt.pos('아버지 가방에 들어가십니다.')
result3 = okt.nouns('나는 어제 보리밥을 먹었다.')

print('result1 :',result1)
print('result2 :',result2)
print('result3 :',result3)
# Out:
# result1 : [('아버지', 'Noun'), ('가', 'Josa'), ('방', 'Noun'), ('에', 'Josa'), ('들어가십니다', 'Verb'), ('.', 'Punctuation')]
# result2 : [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가십니다', 'Verb'), ('.', 'Punctuation')]
# result3 : ['나', '어제', '보리밥']

# %%
# 텍스트 정제
txt_nouns = okt.nouns(txt_data)
txt_nouns
# Out:
# ['스마트', '기기', '덕분', '과거', '때', '데이터', '다음', '그림', '인터넷', '동안', '얼마나', '그림', '글', '천', '건', '포스팅', '클릭', '건', '발생', '데이터', '데이터', '실시간', '분석', '사용자', '패턴', '파악', '거나', '의사', '결정', '데', '참고', '등', '사용', '수', '것', '빅데이터', '처리', '프레임워크', '를', '사용', '페타바이트', '이상', '데이터', '여러', '노드', '구성', '클라우드', '환경', '병렬', '처리', '기법', '함수', '프로그래밍', '일반', '사용', '과', '방식', '사용', '데이터', '처리', '대량', '데이터', '분산', '처리', '수', '기법', '배치', '방식', '데이터', '처리', '때문', '실시간', '데이터', '조회', '단점', '극복', '위해', '최근', '몇', '년', '실시간', '분산', '쿼리', '스트리밍', '처리', '기법', '연구', '실시간', '분산', '쿼리', '클러스터', '구성', '노드', '각자', '쿼리', '처리', '
', '하나', '스크립트', '언어', '사용', '것', '파이썬', '플랫폼', '독립', '적', '타이핑', '대화', '스크립트', '언어', '스크립트', '언어', '지존', '구글', '곳', '사용', '토', '렌트', '마야', '프로그램', '부적', '파이썬', '이용', '데이터', '분석', '위해', '파이썬', '사용', '위해', '등', '라이브러리', '사용', '수', '각', '항목', '대한', '링크', '제', '오픈캐스트', '파이썬', '통합', '개발', '환경', '파이썬', '기본', '를', '제공', '작업', '사용', '점', '작업', '가독성', '폰트', '사용', '소스코드', '입력', '실행', '등', '다소', '점', '좀', '더', '를', '등', '사용', '데이터', '분석', '목적', '파이썬', '사용', '경우', '추천', '제공', '과', '사용', '데이터', '분석', '위', '최적', '환경', '구성', '수', '프로그래밍', '언어', '통계', '계산', '그래픽', '위', '오픈소스', '프로그래밍', '언어', '이자', '패키지', '파이썬', '일반', '사용', '목적', '위', '도구', '은', '통계', '계산', '특화된', '프로그래밍', '언어', '통계학자', '사회과학', '계열', '각', '분야', '연구자', '주로', '사용', '역시', '기본', '환경', '제공', '통합', '개발', '환경', '주로', '사용', '데이터', '분석', '분석', '대상', '단계', '레', '포팅', '단계', '여러', '프로세스', '구성', '전체', '프로세스', '시각', '화가', '차지', '부분', '어쩌면', '분석', '자체', '그', '결과', '사용자', '이해', '전달', '더', '지도', '위', '데이', '보기', '것', '일반', '프로젝트', '별도', '디자이너', '이', '작업', '수행', '포토샵', '일러스트레이터', '사용', '최근', '수집', '데이터', '기본', '대량', '대량', '데이터', '위', '데이터', '체계', '정리', '수집', '보관', '뒤', '데이터', '사용', '수', '데이터베이스', '테이블', '설계', '쿼리', '사용', '능력', '테이블', '설계', '쿼리', '사용', '위', '도구', '저', '를', '사용', '데이터베이스', '설계', '나', '토마토', '시스', '템즈', '개발', '이클립스', '기반', '지능', '도구', '개인', '사용자', '무료', '이용', '수', '현재', '대상', '리', '버스', '포워드', '엔지니어링', '물리', '특성', '편집', '지원', '초보자', '데이터베이스', '설계', '직관', '수', '쿼리', '거', '하나', '충분', '제공', '개발', '도구', '오라클', '데이터베이스', '대한', '데이터베이스', '접속', '지원', '데이터베이스', '여러가지', '쿼리', '통해', '자유', '자재', '데이터',  ...

# %%
# 데이터 변환
str_nouns = " ".join(txt_nouns)

# %%
# 택스트 시각화(단어구름)
wc = WordCloud(width=1200,
               height=1200,
               background_color='white',
               font_path='/content/drive/MyDrive/파이썬 데이터 과학 실습/file/malgun.ttf').generate(str_nouns)

plt.title('Text Word Cloud')
plt.imshow(wc, interpolation='bilinear')
plt.show()
